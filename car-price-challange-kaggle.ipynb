# %%
import pandas as pd

# %%
df = pd.read_csv('car data.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.groupby('Car_Name').mean()
# Out:
#                           Year  Selling_Price  Present_Price     Kms_Driven  \
# Car_Name
# 800                2003.000000       0.350000       2.280000  127000.000000
# Activa 3g          2012.000000       0.310000       0.530000  250250.000000
# Activa 4g          2017.000000       0.400000       0.510000    1300.000000
# Bajaj  ct 100      2015.000000       0.180000       0.320000   35000.000000
# Bajaj Avenger 150  2016.000000       0.750000       0.800000    7000.000000
# ...                        ...            ...            ...            ...
# sx4                2009.333333       3.158333       8.066667   50740.000000
# verna              2013.571429       6.107857       9.400000   42747.285714
# vitara brezza      2018.000000       9.250000       9.830000    2071.000000
# wagon r            2011.250000       2.512500       4.450000   40644.750000
# xcent              2015.333333       4.966667       7.130000   27448.333333
#
#                       Owner
# Car_Name
# ...

# %% [markdown]
# ### Removing two-wheeler from the data
# * we calculate the mean of Present_Price and based on that we put a threshold of 1 lac.

# %%
cardf = df[df.Present_Price > 1.5]
cardf
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
usecols = ['Year','Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner', 'Selling_Price']

# %%
inp = cardf[usecols]

# %%
inp[['Present_Price', 'Kms_Driven','Selling_Price']].corr()
# Out:
#                Present_Price  Kms_Driven  Selling_Price
# Present_Price       1.000000    0.292188       0.835169
# Kms_Driven          0.292188    1.000000      -0.041109
# Selling_Price       0.835169   -0.041109       1.000000

# %% [markdown]
# ### Correlation
# * 'Present_Price', 'Kms_Driven', are numerical values. we calculated corr.
# * we found that 'Present_Price' is 83.5% correlated to our target.
# * Kms_Driven should be corr to diff in Present_Price and selling_price.

# %%
cardf
# Out:
#      Year  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  \
# 0    2014           5.59       27000    Petrol      Dealer       Manual
# 1    2013           9.54       43000    Diesel      Dealer       Manual
# 2    2017           9.85        6900    Petrol      Dealer       Manual
# 3    2011           4.15        5200    Petrol      Dealer       Manual
# 4    2014           6.87       42450    Diesel      Dealer       Manual
# ..    ...            ...         ...       ...         ...          ...
# 296  2016          11.60       33988    Diesel      Dealer       Manual
# 297  2015           5.90       60000    Petrol      Dealer       Manual
# 298  2009          11.00       87934    Petrol      Dealer       Manual
# 299  2017          12.50        9000    Diesel      Dealer       Manual
# 300  2016           5.90        5464    Petrol      Dealer       Manual
#
#      Owner  Selling_Price
# 0        0           3.35
# 1        0           4.75
# ...

# %%
cardf['change'] = cardf['Present_Price'] - cardf['Selling_Price']
# Out:
# <ipython-input-24-7b4a1767961b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cardf['change'] = cardf['Present_Price'] - cardf['Selling_Price']

# %%
cardf[['Kms_Driven', 'change']].corr()
# Out:
#             Kms_Driven    change
# Kms_Driven    1.000000  0.521771
# change        0.521771  1.000000

# %%
cardf.drop('change', axis=1, inplace=True)
# Out:
# C:\Users\parca\anaconda3\envs\venv\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ### Plot the distributions of input features

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.pairplot(cardf)

# %%
sns.histplot(cardf['Year'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %% [markdown]
# ###  Removing the old data (before 2010)
# * We see that most of the cars are after 2010 and car industry has also changed in these years.
# * Training the model on new data will give more accurate results.

# %%
cardfn = cardf[cardf.Year>2010]

# %%
cardfn
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
cardfn[['Present_Price', 'Kms_Driven','Selling_Price']].corr()
# Out:
#                Present_Price  Kms_Driven  Selling_Price
# Present_Price       1.000000    0.321403       0.908485
# Kms_Driven          0.321403    1.000000       0.063988
# Selling_Price       0.908485    0.063988       1.000000

# %% [markdown]
# ### Corrleation improved
# * after removing old data, corr bw Selling_Price and Present_Price improved to 90%

# %%
for col in ['Fuel_Type','Seller_Type','Transmission',]:
    dummies = pd.get_dummies(cardfn[col], prefix=col)
    cardfn = pd.concat([cardfn, dummies], axis=1)    

cardfn['age'] = 2020 - cardfn.Year

dropcols = ['Car_Name', 'Year']+['Fuel_Type','Seller_Type','Transmission',]
cardfn.drop(dropcols, axis=1, inplace=True)

# %%
cardfn
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_CNG  \
# 0             3.35           5.59       27000      0              0
# 1             4.75           9.54       43000      0              0
# 2             7.25           9.85        6900      0              0
# 3             2.85           4.15        5200      0              0
# 4             4.60           6.87       42450      0              0
# ..             ...            ...         ...    ...            ...
# 295           8.55          13.09       60076      0              0
# 296           9.50          11.60       33988      0              0
# 297           4.00           5.90       60000      0              0
# 299          11.50          12.50        9000      0              0
# 300           5.30           5.90        5464      0              0
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0                   0                 1                   1
# ...

# %%
sns.pairplot(cardfn)

# %% [markdown]
# ### Train and test dataset

# %%
X, y = cardfn.drop('Selling_Price', axis=1), cardfn.Selling_Price
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Scaling the input features
# * train the scaler on training dataset
# * transform test data using trained scaler

# %%
from joblib import dump, load
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn import metrics

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', Ridge())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  0.9760991540226681
# mean_squared_error =  0.7454854202752731
# r2_score = 0.9691925773683948

# %%
model = Pipeline(verbose=1, steps=[
#     ('scaler', StandardScaler()),
#     ('polyfeats', PolynomialFeatures()),
    ('ridge', Ridge())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............. (step 1 of 1) Processing ridge, total=   0.0s
# explained_variance_score =  0.9362100966697191
# mean_squared_error =  1.5619079640281108
# r2_score = 0.9354536554964199

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
#     ('polyfeats', PolynomialFeatures()),
    ('ridge', Ridge())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing ridge, total=   0.0s
# explained_variance_score =  0.9355734647108385
# mean_squared_error =  1.5854058549137122
# r2_score = 0.934482597665139

# %%
model = Pipeline(verbose=1, steps=[
#     ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', Ridge())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ......... (step 1 of 2) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing ridge, total=   0.0s
# explained_variance_score =  0.9696117392589654
# mean_squared_error =  0.9361069374518906
# r2_score = 0.9613150824065626
# C:\Users\parca\anaconda3\envs\venv\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.17398e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,

# %%
from sklearn.linear_model import LinearRegression, Lasso, SGDRegressor, RidgeCV

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', LinearRegression())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  0.9411303509551695
# mean_squared_error =  1.4387824976870889
# r2_score = 0.940541854641724

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', Lasso())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  0.7323745558199588
# mean_squared_error =  7.292565313802899
# r2_score = 0.6986324137527036

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', SGDRegressor())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  -5.33470305051302e+18
# mean_squared_error =  1.801764584252046e+20
# r2_score = -7.445849579353915e+18

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', RidgeCV())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  0.9755530958026711
# mean_squared_error =  0.7306352858307155
# r2_score = 0.9698062639081003

# %%
from sklearn.linear_model import OrthogonalMatchingPursuit, LassoLarsIC, Lars, ElasticNet

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', OrthogonalMatchingPursuit())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  0.9808487326893169
# mean_squared_error =  0.5769878546544767
# r2_score = 0.9761557929797205

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', LassoLarsIC())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  0.919613180369818
# mean_squared_error =  2.112944039920951
# r2_score = 0.9126819140061254
# C:\Users\parca\anaconda3\envs\venv\lib\site-packages\sklearn\linear_model\_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.705e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# ...

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', Lars())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  -6.349479547649172e+31
# mean_squared_error =  1.642605844302934e+33
# r2_score = -6.788121013003751e+31
# C:\Users\parca\anaconda3\envs\venv\lib\site-packages\sklearn\linear_model\_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=3.598e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# ...

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', ElasticNet())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  0.8230241213856084
# mean_squared_error =  4.479238176036894
# r2_score = 0.8148940545264665

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', OrthogonalMatchingPursuit())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  0.9808487326893169
# mean_squared_error =  0.5769878546544767
# r2_score = 0.9761557929797205

# %%
model = Pipeline(verbose=1, steps=[
    ('scaler', StandardScaler()),
    ('polyfeats', PolynomialFeatures()),
    ('ridge', Ridge())
])
model = model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('explained_variance_score = ', metrics.explained_variance_score(y_test, y_pred))
print('mean_squared_error = ', metrics.mean_squared_error(y_test, y_pred))
print(f'\033[1mr2_score = { metrics.r2_score(y_test, y_pred)}\033[0m')
# Out:
# [Pipeline] ............ (step 1 of 3) Processing scaler, total=   0.0s
# [Pipeline] ......... (step 2 of 3) Processing polyfeats, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing ridge, total=   0.0s
# explained_variance_score =  0.9760991540226681
# mean_squared_error =  0.7454854202752731
# r2_score = 0.9691925773683948

# %%
y_pred
# Out:
# array([ 5.27246103,  8.48690977,  8.16710123,  5.10276205,  4.46555718,
#         8.22631852,  3.48485415,  5.72327607,  5.10411569,  4.04029572,
#         7.46933933,  9.01352915, 24.7480305 , 10.64401771, 19.79746722,
#         8.90900677,  5.20712421,  6.59973766,  1.56551826])

# %%
y_test.values
# Out:
# array([ 4.9 ,  7.75,  8.35,  6.  ,  3.9 ,  7.25,  4.15,  4.75,  4.95,
#         4.85,  7.9 ,  8.65, 23.  , 10.11, 18.  ,  7.75,  4.5 ,  5.85,
#         1.65])

# %%
dump(model, 'OrthogonalMatchingPursuit_model.joblib')
model = load('OrthogonalMatchingPursuit_model.joblib')

# %% [markdown]
# ### make test pipeline

# %%
val_dict = {
    'Year':2018,
    'Present_Price':5.7,
    'Kms_Driven':6500,
    'Fuel_Type':'Diesel',
    'Seller_Type':'Dealer',
    'Transmission':'Automatic',
    'Owner':0,
}

testdf = pd.DataFrame([val_dict])
for col in ['Fuel_Type','Seller_Type','Transmission',]:
    dummies = pd.get_dummies(testdf[col], prefix=col)
    testdf = pd.concat([testdf, dummies], axis=1)    
testdf['age'] = 2020 - testdf.Year

dropcols = ['Year']+['Fuel_Type','Seller_Type','Transmission',]
testdf.drop(dropcols, axis=1, inplace=True)

columns = ['Present_Price', 'Kms_Driven', 'Owner', 'Fuel_Type_CNG',
       'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Dealer',
       'Seller_Type_Individual', 'Transmission_Automatic',
       'Transmission_Manual', 'age']
testdf = pd.concat([testdf, pd.DataFrame([], columns=columns)]).fillna(0)[columns]

# %%
testdf
# Out:
#    Present_Price  Kms_Driven  Owner  Fuel_Type_CNG  Fuel_Type_Diesel  \
# 0            5.7        6500      0              0                 1
#
#    Fuel_Type_Petrol  Seller_Type_Dealer  Seller_Type_Individual  \
# 0                 0                   1                       0
#
#    Transmission_Automatic  Transmission_Manual  age
# 0                       1                    0   10

# %%
tpoint = testdf.values

y_pred = model.predict(tpoint)
y_pred
# Out:
# array([4.29850841])
